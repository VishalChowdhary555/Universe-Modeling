# %%
# Install and import necessary libraries
# !pip install sympy matplotlib numpy

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
matter_density = 0.10  # 10% Matter
antimatter_density = 0.05  # 5% Antimatter
dark_matter_dark_energy_density = 0.85  # 85% Dark Matter and Dark Energy combined

# Hubble parameter at present time in km/s/Mpc and its conversion to SI units
H0 = 70  # km/s/Mpc
H0_SI = H0 * 1e3 / (3.086e22)  # Convert to s^-1

# Define the scale factor symbolically
a = sp.symbols('a')

# Define the critical density
G = 6.67430e-11  # Gravitational constant in m^3 kg^-1 s^-2
rho_crit = 3 * (H0_SI**2) / (8 * np.pi * G)  # Critical density

# Define the densities in terms of critical density
rho_matter = matter_density * rho_crit
rho_antimatter = antimatter_density * rho_crit
rho_dark = dark_matter_dark_energy_density * rho_crit

# Define the Friedmann equation
# Note: We're assuming a flat universe (k = 0) and no cosmological constant (Λ = 0) for simplicity
H = sp.Function('H')(a)
friedmann_eq = H**2 - (8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark) / a**3

# Solve the Friedmann equation for H(a)
H_sol = sp.sqrt((8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark) / a**3)

# Generate data for plotting
a_vals = np.linspace(0.1, 10, 400)  # Scale factor range from 0.1 to 10
H_vals = [float(H_sol.evalf(subs={a: a_val})) for a_val in a_vals]

# Plot the results
plt.plot(a_vals, H_vals)
plt.xlabel("Scale Factor (a)")
plt.ylabel("Hubble Parameter (H)")
plt.title("Universe Model with 10% Matter, 5% Antimatter, 85% Dark Matter and Dark Energy")
plt.grid(True)
plt.show()

# %%
# Install and import necessary libraries
# !pip install sympy matplotlib numpy

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
matter_density = 0.10
antimatter_density = 0.05
dark_matter_density = 0.85  # Assuming dark matter and dark energy combined

# Critical density
H0 = 70  # Hubble parameter (km/s/Mpc)
H0_SI = H0 * 1e3 / (3.086e22)  # Hubble parameter in s^-1

# Define the Friedmann equation using sympy
a = sp.symbols('a')
H = sp.Function('H')(a)

# Friedmann equation parameters
G = 6.67430e-11  # Gravitational constant in m^3 kg^-1 s^-2
k = 0  # Assuming a flat universe
Λ = 0  # Assuming no cosmological constant for simplicity

# Define the densities in terms of critical density
rho_crit = 3 * (H0_SI**2) / (8 * np.pi * G)
rho_matter = matter_density * rho_crit
rho_antimatter = antimatter_density * rho_crit
rho_dark = dark_matter_density * rho_crit

# Friedmann equation
friedmann_eq = H**2 - (8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark) / a**3 - k / a**2 + Λ / 3

# Solve the Friedmann equation
H_sol = sp.sqrt((8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark) / a**3 - k / a**2 + Λ / 3)

# Generate data for plotting
a_vals = np.linspace(0.1, 10, 400)  # Scale factor range
H_vals = [float(H_sol.evalf(subs={a: a_val})) for a_val in a_vals]

# Plot the results
plt.plot(a_vals, H_vals)
plt.xlabel("Scale Factor (a)")
plt.ylabel("Hubble Parameter (H)")
plt.title("Universe Model with 10% Matter, 5% Antimatter, 85% Dark Matter and Dark Energy")
plt.grid(True)
plt.show()

# %%
# Install and import necessary libraries
# !pip install sympy matplotlib numpy

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
matter_density = 0.10
antimatter_density = 0.05
dark_matter_dark_energy_density = 0.85  # Assuming dark matter and dark energy combined

# Hubble constant (in SI units)
H0 = 70  # Hubble parameter (km/s/Mpc)
H0_SI = H0 * 1e3 / (3.086e22)  # Hubble parameter in s^-1

# Define the Friedmann equation using sympy
a = sp.symbols('a')
H = sp.Function('H')(a)

# Friedmann equation parameters
G = 6.67430e-11  # Gravitational constant in m^3 kg^-1 s^-2
k = 0  # Assuming a flat universe
Λ = 0  # Assuming no cosmological constant for simplicity

# Define the densities in terms of critical density
rho_crit = 3 * (H0_SI**2) / (8 * np.pi * G)
rho_matter = matter_density * rho_crit
rho_antimatter = antimatter_density * rho_crit
rho_dark = dark_matter_dark_energy_density * rho_crit

# Friedmann equation
friedmann_eq = H**2 - (8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark) / a**3 - k / a**2 + Λ / 3

# Solve the Friedmann equation
H_sol = sp.sqrt((8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark) / a**3 - k / a**2 + Λ / 3)

# Generate data for plotting
a_vals = np.linspace(0.1, 10, 400)  # Scale factor range
H_vals = [float(H_sol.evalf(subs={a: a_val})) for a_val in a_vals]

# Plot the results
plt.plot(a_vals, H_vals)
plt.xlabel("Scale Factor (a)")
plt.ylabel("Hubble Parameter (H)")
plt.title("Universe Model with 10% Matter, 5% Antimatter, 85% Dark Matter and Dark Energy")
plt.grid(True)
plt.show()

# %%
# Install and import necessary libraries
# !pip install sympy matplotlib numpy

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
matter_density = 0.10
antimatter_density = 0.05
dark_matter_density = 0.30  # Assuming dark matter is 30%
dark_energy_density = 0.55  # Dark energy is 55%

# Hubble constant (in SI units)
H0 = 70  # Hubble parameter (km/s/Mpc)
H0_SI = H0 * 1e3 / (3.086e22)  # Hubble parameter in s^-1

# Define the Friedmann equation using sympy
a = sp.symbols('a')
H = sp.Function('H')(a)

# Friedmann equation parameters
G = 6.67430e-11  # Gravitational constant in m^3 kg^-1 s^-2
Λ = dark_energy_density * 3 * (H0_SI**2)  # Cosmological constant

# Define the densities in terms of critical density
rho_crit = 3 * (H0_SI**2) / (8 * np.pi * G)
rho_matter = matter_density * rho_crit
rho_antimatter = antimatter_density * rho_crit
rho_dark_matter = dark_matter_density * rho_crit

# Friedmann equation
friedmann_eq = H**2 - (8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark_matter) / a**3 - Λ / 3

# Solve the Friedmann equation
H_sol = sp.sqrt((8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark_matter) / a**3 + Λ / 3)

# Generate data for plotting
a_vals = np.linspace(0.1, 10, 400)  # Scale factor range
H_vals = [float(H_sol.evalf(subs={a: a_val})) for a_val in a_vals]

# Plot the results
plt.plot(a_vals, H_vals)
plt.xlabel("Scale Factor (a)")
plt.ylabel("Hubble Parameter (H)")
plt.title("Universe Model with 10% Matter, 5% Antimatter, 30% Dark Matter, 55% Dark Energy")
plt.grid(True)
plt.show()

# %%
# Install and import necessary libraries
# !pip install sympy matplotlib numpy

import sympy as sp
import numpy as np
import matplotlib.pyplot as plt

# Define the parameters
matter_density = 0.10
antimatter_density = 0.05
dark_matter_density = 0.30  # Dark matter
dark_energy_density = 0.55  # Dark energy

# Hubble constant (in SI units)
H0 = 70  # Hubble parameter (km/s/Mpc)
H0_SI = H0 * 1e3 / (3.086e22)  # Hubble parameter in s^-1

# Define the Friedmann equation using sympy
a = sp.symbols('a')
H = sp.Function('H')(a)

# Friedmann equation parameters
G = 6.67430e-11  # Gravitational constant in m^3 kg^-1 s^-2
rho_crit = 3 * (H0_SI**2) / (8 * np.pi * G)

# Debug: Print critical density
print(f"Critical Density: {rho_crit:.2e} kg/m^3")

# Energy densities in terms of critical density
rho_matter = matter_density * rho_crit
rho_antimatter = antimatter_density * rho_crit
rho_dark_matter = dark_matter_density * rho_crit
rho_dark_energy = dark_energy_density * rho_crit

# Debug: Print each component's density
print(f"Matter Density: {rho_matter:.2e} kg/m^3")
print(f"Antimatter Density: {rho_antimatter:.2e} kg/m^3")
print(f"Dark Matter Density: {rho_dark_matter:.2e} kg/m^3")
print(f"Dark Energy Density: {rho_dark_energy:.2e} kg/m^3")

# Cosmological constant (Lambda) term
Λ = dark_energy_density * 3 * (H0_SI**2)

# Debug: Print cosmological constant
print(f"Cosmological Constant (Lambda): {Λ:.2e} s^-2")

# Define the Friedmann equation
friedmann_eq = H**2 - (8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark_matter) / a**3 - Λ / 3

# Solve the Friedmann equation for H(a)
H_sol = sp.sqrt((8 * sp.pi * G / 3) * (rho_matter + rho_antimatter + rho_dark_matter) / a**3 + Λ / 3)

# Generate data for plotting
a_vals = np.linspace(0.1, 10, 400)  # Scale factor range
H_vals = [float(H_sol.evalf(subs={a: a_val})) for a_val in a_vals]

# Plot the results
plt.plot(a_vals, H_vals)
plt.xlabel("Scale Factor (a)")
plt.ylabel("Hubble Parameter (H)")
plt.title("Universe Model with 10% Matter, 5% Antimatter, 30% Dark Matter, 55% Dark Energy")
plt.grid(True)
plt.show()
# Out:
# ...
# Critical Density: 9.20e-27 kg/m^3
# Matter Density: 9.20e-28 kg/m^3
# Antimatter Density: 4.60e-28 kg/m^3
# Dark Matter Density: 2.76e-27 kg/m^3
# Dark Energy Density: 5.06e-27 kg/m^3
# Cosmological Constant (Lambda): 8.49e-36 s^-2
